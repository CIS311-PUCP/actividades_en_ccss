# %%
u"\U0001F308"
# Out:
# '🌈'

# %%
import pandas as pd

# %%
enc_lgbt = pd.read_spss("/Users/ccsuehara/Downloads/602-Modulo1287.sav")

# %%
enc_lgbt
# Out:
#        USUARIO_ID                                               p101  \
# 0            94.0                                Sin nivel educativo
# 1           177.0                                      No especificó
# 2           183.0  Superior No Universitaria Incompleta (Técnica-...
# 3           187.0                    Superior Universitaria Completa
# 4           188.0  Superior No Universitaria Completa (Técnica-3 ...
# ...           ...                                                ...
# 12021     87185.0                    Superior Universitaria Completa
# 12022     87187.0                    Superior Universitaria Completa
# 12023     87188.0                  Superior Universitaria Incompleta
# 12024     87189.0                    Superior Universitaria Completa
# 12025     87190.0                                Secundaria Completa
#
#                 p102                                p103  \
# 0                 No                 Por falta de dinero
# ...
