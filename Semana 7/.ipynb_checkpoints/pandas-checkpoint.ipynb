# %% [markdown]
# # Pandas (Parte 1)

# %% [markdown]
# Pandas es la librería más popular de Python para realizar análisis de datos. Esta se especializa en trabajar con ciertos tipos de datos. Los más importantes son:
#
# - Data tabular, como los dataframes
# - Series
# - Matrices de datos
# - Series de tiempo
#
# Los objetos de Pandas más importantes son 2:
# - Series
# - Dataframes  (Estas clases se enfocarán en trabajar con dataframes).
#
# Esta librería es un _must_ en el aprendizaje del análisis de datos, machine learning, etc por una serie de motivos:
#
# - Se integra perfectamente con librerías como scikit-learn (machine learning), matplotlib, seaborn y altair (visualización de datos), statsmodels (modelos estadísticos listos para usar), y un gran etcétera.
#
# - La gran parte de la comunidad que hace data analysis, y que se apoya mediante foros y demás, usa Pandas.
# - Pandas es muy amplio y tiene muchas funcionalidades.

# %% [markdown]
# ### 1. Importar pandas

# %%
import pandas as pd

# %% [markdown]
# ### 2. Hacer disponible nuestro dataframe
#
# - Casi SIEMPRE trabajaremos con dataframes.
#
#
# Pero qué es un dataframe?
#
# - Es una estructura de datos de dos dimensiones (fila-columna).
# - Cada fila es una observación, y cada columna, una variable (atributo, feature, etc).
# - El dataframe sirve para representar bases de datos.
#
#
# 2 maneras: crearlo por nosotros mismos ó leer datos

# %% [markdown]
# ####  Una forma simple de crear dataframes:

# %%
nombres_columnas = ['nombre', 'edad']

obs1 = ['Cristina', 32]
obs2 = ['Diego',  21]

data = [obs1, obs2]

ejemplo_df = pd.DataFrame(data = data, columns = nombres_columnas)
ejemplo_df
# Out:
#      nombre  edad
# 0  Cristina    32
# 1     Diego    21

# %% [markdown]
# #### Otra forma de hacerlo

# %%
df = pd.DataFrame()
df['nombre'] = ['Cristina', 'Diego']
df['edad'] = [32 , 21]
df['direccion'] = ["pueblo libre", "magdalena"]

df
# Out:
#      nombre  edad     direccion
# 0  Cristina    32  pueblo libre
# 1     Diego    21     magdalena

# %% [markdown]
# #### Leyendo la información:
# Los archivos que tenemos pueden estar en distintos formatos: dta, sav, json, csv, txt. Pandas puede leer cualquiera de dichos archivos.

# %%
locacion_datos = "https://otorongo.club/2021/json/ingresos/"

cong = pd.read_json(locacion_datos) ## Hacer esto tiene el mismo efecto que haber guardado el archivo en PC

# %%
cong ## Nos da una representación del dataframe cong
# Out:
#                                 nombre       dni                      partido  \
# 0         SEMPERTEGUI ILATOMA GILBERTO  27428781            VICTORIA NACIONAL
# 1                LUNA GALVEZ JOSE LEON   7246887                 PODEMOS PERU
# 2                KUOMAN SAAVEDRA DAVID   7818712           RENOVACION POPULAR
# 3                  ACUÑA PERALTA CESAR  17903382     ALIANZA PARA EL PROGRESO
# 4       OTIVO MANTURANO TITO ALBERTICO  19873483  RENACIMIENTO UNIDO NACIONAL
# ...                                ...       ...                          ...
# 3311  GUTIERREZ RIVERA SUSANA CAROLINA  44720712                 PODEMOS PERU
# 3312     CISNEROS CALDERON ANIBAL HUGO   8505376  RENACIMIENTO UNIDO NACIONAL
# 3313    GONZALES FLORES LIZBETH ROXANA  48855918                 PODEMOS PERU
# 3314     MELGAR GALVEZ FIORELA JUSETTE  70013249                 PODEMOS PERU
# 3315           HUARI AVILA ERICK DAVID  72765718           RENOVACION POPULAR
#
#       total_ingreso  ingreso_publico  ingreso_privado  renta_publico  \
# 0          57560800          2710800         14400000              0
# 1          12428083                0          1732402              0
# 2          10998927                0            92096              0
# 3           9571448                0          3063448              0
# 4           7740000          3060000                0              0
# ...             ...              ...              ...            ...
# 3311              0                0                0              0
# 3312              0                0                0              0
# 3313              0                0                0              0
# 3314              0                0                0              0
# 3315              0                0                0              0
#
#       renta_privado  otro_ingreso_publico  otro_ingreso_privado
# 0                 0                     0              40450000
# 1                 0                     0              10695681
# 2                 0                     0              10906831
# 3                 0                     0               6508000
# 4           1800000                     0               2880000
# ...             ...                   ...                   ...
# 3311              0                     0                     0
# 3312              0                     0                     0
# 3313              0                     0                     0
# 3314              0                     0                     0
# 3315              0                     0                     0
#
# [3316 rows x 10 columns]

# %%
cong.head() ## Nos da las primeras observaciones del dataframe
# Out:
#                            nombre       dni                      partido  \
# 0    SEMPERTEGUI ILATOMA GILBERTO  27428781            VICTORIA NACIONAL
# 1           LUNA GALVEZ JOSE LEON   7246887                 PODEMOS PERU
# 2           KUOMAN SAAVEDRA DAVID   7818712           RENOVACION POPULAR
# 3             ACUÑA PERALTA CESAR  17903382     ALIANZA PARA EL PROGRESO
# 4  OTIVO MANTURANO TITO ALBERTICO  19873483  RENACIMIENTO UNIDO NACIONAL
#
#    total_ingreso  ingreso_publico  ingreso_privado  renta_publico  \
# 0       57560800          2710800         14400000              0
# 1       12428083                0          1732402              0
# 2       10998927                0            92096              0
# 3        9571448                0          3063448              0
# 4        7740000          3060000                0              0
#
#    renta_privado  otro_ingreso_publico  otro_ingreso_privado
# 0              0                     0              40450000
# 1              0                     0              10695681
# 2              0                     0              10906831
# 3              0                     0               6508000
# 4        1800000                     0               2880000

# %%
cong.tail() ## Nos da las últimas observaciones del dataframe.
# Out:
#                                 nombre       dni                      partido  \
# 3311  GUTIERREZ RIVERA SUSANA CAROLINA  44720712                 PODEMOS PERU
# 3312     CISNEROS CALDERON ANIBAL HUGO   8505376  RENACIMIENTO UNIDO NACIONAL
# 3313    GONZALES FLORES LIZBETH ROXANA  48855918                 PODEMOS PERU
# 3314     MELGAR GALVEZ FIORELA JUSETTE  70013249                 PODEMOS PERU
# 3315           HUARI AVILA ERICK DAVID  72765718           RENOVACION POPULAR
#
#       total_ingreso  ingreso_publico  ingreso_privado  renta_publico  \
# 3311              0                0                0              0
# 3312              0                0                0              0
# 3313              0                0                0              0
# 3314              0                0                0              0
# 3315              0                0                0              0
#
#       renta_privado  otro_ingreso_publico  otro_ingreso_privado
# 3311              0                     0                     0
# 3312              0                     0                     0
# 3313              0                     0                     0
# 3314              0                     0                     0
# 3315              0                     0                     0

# %%
## Abrir un archivo spss es muy parecido a abrir un archivo dta 
enc_lgbt = pd.read_spss("/Users/ccsuehara/Downloads/602-Modulo1287.sav")

# %%
enc_lgbt.head(5)
# Out:
#    USUARIO_ID                                               p101  \
# 0        94.0                                Sin nivel educativo
# 1       177.0                                      No especificó
# 2       183.0  Superior No Universitaria Incompleta (Técnica-...
# 3       187.0                    Superior Universitaria Completa
# 4       188.0  Superior No Universitaria Completa (Técnica-3 ...
#
#             p102                                p103  \
# 0             No                 Por falta de dinero
# 1  No especificó                                 NaN
# 2             Si                                 NaN
# 3             No  Porqué ya concluí con mis estudios
# 4             No  Porqué ya concluí con mis estudios
#
#                                 Rp103 p103esp p104_1 p104_2 p104_3 p104_4  \
# 0                 Por falta de dinero             Si     No     Si     No
# 1                                 NaN             No     No     No     No
# 2                                 NaN             No     Si     No     No
# 3  Porqué ya concluí con mis estudios             No     No     No     Si
# 4  Porqué ya concluí con mis estudios             No     No     No     No
#
#    ...  ubigeo      depa               lima ubi_nac depa_nac  \
# 0  ...  030301  Apurímac                     120304    Junín
# 1  ...  150135      Lima  Provincia de Lima  150115     Lima
# 2  ...  150125      Lima  Provincia de Lima  150121     Lima
# 3  ...  150111      Lima  Provincia de Lima  150103     Lima
# 4  ...  150136      Lima  Provincia de Lima  150133     Lima
#
#             lima_nac          gedad                                 ocupacion  \
# 0                     Menores de 20                             No especifico
# 1  Provincia de Lima        25 - 29  Profesiones, Científicos e Intelectuales
# 2  Provincia de Lima  Menores de 20                                       NaN
# 3  Provincia de Lima        20 - 24  Profesiones, Científicos e Intelectuales
# 4  Provincia de Lima        20 - 24        Técnicos y trabajadores asimilados
#
#                     rama2      hacinamiento
# 0           No especifico  Sin hacinamiento
# 1               Enseñanza  Sin hacinamiento
# 2                     NaN  Sin hacinamiento
# 3  Hoteles y restaurantes  Sin hacinamiento
# 4  Hoteles y restaurantes  Sin hacinamiento
#
# [5 rows x 318 columns]

# %%
mod_1 = pd.read_stata("/Users/ccsuehara/Downloads/687-Modulo01 2/enaho01-2019-100.dta")

# %%
mod_1
# Out:
#         aÑo mes nconglome conglome vivienda hogar  ubigeo       dominio  \
# 0      2019  10    007060   005001      007    11  010101  sierra norte
# 1      2019  10    007060   005001      017    11  010101  sierra norte
# 2      2019  10    007060   005001      028    11  010101  sierra norte
# 3      2019  10    007060   005001      040    11  010101  sierra norte
# 4      2019  10    007060   005001      050    11  010101  sierra norte
# ...     ...  ..       ...      ...      ...   ...     ...           ...
# 43863  2019  12    043948   011350      022    11  180101     costa sur
# 43864  2019  12    043948   011350      059    11  180101     costa sur
# 43865  2019  12    043948   011350      078    11  180101     costa sur
# 43866  2019  12    043948   011350      097    11  180101     costa sur
# 43867  2019  12    043948   011350      116    11  180101     costa sur
#
#                               estrato  periodo  ...  \
# 0       de 20 000 a 49 999 habitantes        1  ...
# 1       de 20 000 a 49 999 habitantes        1  ...
# 2       de 20 000 a 49 999 habitantes        1  ...
# 3       de 20 000 a 49 999 habitantes        1  ...
# 4       de 20 000 a 49 999 habitantes        1  ...
# ...                               ...      ...  ...
# 43863   de 50 000 a 99 999 habitantes        2  ...
# 43864   de 50 000 a 99 999 habitantes        2  ...
# 43865   de 50 000 a 99 999 habitantes        2  ...
# 43866   de 50 000 a 99 999 habitantes        2  ...
# 43867   de 50 000 a 99 999 habitantes        2  ...
#
#                             nbi2  \
# 0      vivienda sin hacinamiento
# 1      vivienda sin hacinamiento
# 2                            NaN
# 3      vivienda sin hacinamiento
# 4      vivienda sin hacinamiento
# ...                          ...
# 43863  vivienda sin hacinamiento
# 43864  vivienda sin hacinamiento
# 43865  vivienda sin hacinamiento
# 43866  vivienda con hacinamiento
# 43867  vivienda sin hacinamiento
#
#                                                 nbi3  \
# 0      hogares con vivienda con servicios higienicos
# 1      hogares con vivienda con servicios higienicos
# 2                                                NaN
# 3      hogares con vivienda sin servicios hogienicos
# 4      hogares con vivienda con servicios higienicos
# ...                                              ...
# 43863  hogares con vivienda con servicios higienicos
# 43864  hogares con vivienda sin servicios hogienicos
# 43865  hogares con vivienda sin servicios hogienicos
# 43866  hogares con vivienda con servicios higienicos
# 43867  hogares con vivienda con servicios higienicos
#
#                                              nbi4  \
# 0      hogares con niños que asisten a la escuela
# 1      hogares con niños que asisten a la escuela
# 2                                             NaN
# 3      hogares con niños que asisten a la escuela
# 4      hogares con niños que asisten a la escuela
# ...                                           ...
# 43863  hogares con niños que asisten a la escuela
# 43864  hogares con niños que asisten a la escuela
# 43865  hogares con niños que asisten a la escuela
# 43866  hogares con niños que asisten a la escuela
# 43867  hogares con niños que asisten a la escuela
#
#                                          nbi5 codccpp  \
# 0      hogares sin alta dependencia económica    0001
# 1      hogares sin alta dependencia económica    0001
# 2                                         NaN    0001
# 3      hogares sin alta dependencia económica    0001
# 4      hogares sin alta dependencia económica    0001
# ...                                       ...     ...
# 43863  hogares sin alta dependencia económica    0023
# 43864  hogares sin alta dependencia económica    0023
# 43865  hogares sin alta dependencia económica    0023
# 43866  hogares sin alta dependencia económica    0023
# 43867  hogares sin alta dependencia económica    0023
#
#                                               nomccpp    latitud  longitud  \
# 0                    AA HH SANTO TORIBIO DE MOGROVEJO  -6.228422 -77.87709
# 1                    AA HH SANTO TORIBIO DE MOGROVEJO  -6.228422 -77.87709
# 2                    AA HH SANTO TORIBIO DE MOGROVEJO  -6.228422 -77.87709
# 3                                  CIUDAD CHACHAPOYAS  -6.228422 -77.87709
# 4                                  CIUDAD CHACHAPOYAS  -6.228422 -77.87709
# ...                                               ...        ...       ...
# 43863           ASOCIACION DE VIVIENDA BELLO AMANECER -17.212933 -70.93914
# 43864  ASOCIACION DE VIVIENDA LOS ROSALES 14 DE JUNIO -17.212933 -70.93914
# 43865              ASOCIACION DE VIVIENDA LOS ROSALES -17.212933 -70.93914
# 43866           ASOCIACION DE VIVIENDA BELLO AMANECER -17.212933 -70.93914
# 43867           ASOCIACION DE VIVIENDA BELLO AMANECER -17.212933 -70.93914
#
#       altura   factor07
# 0       2348  79.745071
# 1       2348  79.745071
# 2       2348  79.745071
# 3       2348  79.745071
# 4       2348  79.745071
# ...      ...        ...
# 43863   1427  80.257660
# 43864   1427  80.257660
# 43865   1427  80.257660
# 43866   1427  80.257660
# 43867   1427  80.257660
#
# [43868 rows x 323 columns]

# %% [markdown]
# #### Explorando la base de datos que tenemos.

# %% [markdown]
# El primer paso de nuestro análisis siempre tiene que ser entender las datos. Para ello seguimos los siguientes pasos:

# %%
cong.info()  ## Obtenemos el nombre de las columnas, si es que hay valores faltantes (missing values)  y el tipo de cada una de las cols
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3316 entries, 0 to 3315
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   nombre                3316 non-null   object
#  1   dni                   3316 non-null   int64
#  2   partido               3316 non-null   object
#  3   total_ingreso         3316 non-null   int64
#  4   ingreso_publico       3316 non-null   int64
#  5   ingreso_privado       3316 non-null   int64
#  6   renta_publico         3316 non-null   int64
#  7   renta_privado         3316 non-null   int64
#  8   otro_ingreso_publico  3316 non-null   int64
#  9   otro_ingreso_privado  3316 non-null   int64
# dtypes: int64(8), object(2)
# memory usage: 259.2+ KB

# %%
cong.shape  ### Nos ayuda a ver las dimensiones de nuestra base de datos. 
### en este caso: 3316 candidatos a congresistas/presidentes y 10 variables
# Out:
# (3316, 10)

# %%
nomb_variables = cong.columns  ## Nos da un array con el nombre de las variables que componen la base de datos

# %%
for nomb in nomb_variables:
    print(nomb)
# Out:
# nombre
# dni
# partido
# total_ingreso
# ingreso_publico
# ingreso_privado
# renta_publico
# renta_privado
# otro_ingreso_publico
# otro_ingreso_privado

# %%
cong.describe() ## Da las medidas centrales de las variables numéricas
# Out:
#                 dni  total_ingreso  ingreso_publico  ingreso_privado  \
# count  3.316000e+03   3.316000e+03     3.316000e+03     3.316000e+03
# mean   2.711041e+07   8.834971e+04     1.637062e+04     1.901372e+04
# std    1.949365e+07   1.077207e+06     7.957965e+04     2.682862e+05
# min    8.800000e+01   0.000000e+00     0.000000e+00     0.000000e+00
# 25%    9.262936e+06   1.050000e+04     0.000000e+00     0.000000e+00
# 50%    2.392150e+07   2.685900e+04     0.000000e+00     0.000000e+00
# 75%    4.256423e+07   5.682600e+04     1.052400e+04     0.000000e+00
# max    8.067886e+07   5.756080e+07     3.060000e+06     1.440000e+07
#
#        renta_publico  renta_privado  otro_ingreso_publico  \
# count    3316.000000   3.316000e+03           3316.000000
# mean     3630.140229   1.280850e+04           1278.965621
# std     16814.197864   7.170759e+04          13259.996009
# min         0.000000   0.000000e+00              0.000000
# 25%         0.000000   0.000000e+00              0.000000
# 50%         0.000000   0.000000e+00              0.000000
# 75%         0.000000   1.000000e+04              0.000000
# max    300000.000000   2.750000e+06         487589.000000
#
#        otro_ingreso_privado
# count          3.316000e+03
# mean           3.524777e+04
# std            7.741160e+05
# min            0.000000e+00
# 25%            0.000000e+00
# 50%            0.000000e+00
# 75%            0.000000e+00
# max            4.045000e+07

# %% [markdown]
# #### Cómo seleccionar datos
#
# A veces sólo necesitamos entender una parte de todos nuestros datos. Por ejemplo, queremos ver los datos de los partidos políticos:

# %%
cong.partido ## 1era forma
# Out:
# 0                 VICTORIA NACIONAL
# 1                      PODEMOS PERU
# 2                RENOVACION POPULAR
# 3          ALIANZA PARA EL PROGRESO
# 4       RENACIMIENTO UNIDO NACIONAL
#                    ...
# 3311                   PODEMOS PERU
# 3312    RENACIMIENTO UNIDO NACIONAL
# 3313                   PODEMOS PERU
# 3314                   PODEMOS PERU
# 3315             RENOVACION POPULAR
# Name: partido, Length: 3316, dtype: object

# %%
cong['partido'] # 2da forma
# Out:
# 0                 VICTORIA NACIONAL
# 1                      PODEMOS PERU
# 2                RENOVACION POPULAR
# 3          ALIANZA PARA EL PROGRESO
# 4       RENACIMIENTO UNIDO NACIONAL
#                    ...
# 3311                   PODEMOS PERU
# 3312    RENACIMIENTO UNIDO NACIONAL
# 3313                   PODEMOS PERU
# 3314                   PODEMOS PERU
# 3315             RENOVACION POPULAR
# Name: partido, Length: 3316, dtype: object

# %%
cong['nombre partido'] = cong['partido']

# %%
cong['nombre partido']
# Out:
# 0                 VICTORIA NACIONAL
# 1                      PODEMOS PERU
# 2                RENOVACION POPULAR
# 3          ALIANZA PARA EL PROGRESO
# 4       RENACIMIENTO UNIDO NACIONAL
#                    ...
# 3311                   PODEMOS PERU
# 3312    RENACIMIENTO UNIDO NACIONAL
# 3313                   PODEMOS PERU
# 3314                   PODEMOS PERU
# 3315             RENOVACION POPULAR
# Name: nombre partido, Length: 3316, dtype: object

# %%
## A veces queremos contar los valores únicos de una sola columna

cong['partido'].value_counts()
# Out:
# ALIANZA PARA EL PROGRESO                          179
# FRENTE POPULAR AGRICOLA FIA DEL PERU - FREPAP     178
# PARTIDO DEMOCRATICO SOMOS PERU                    178
# PARTIDO POLITICO NACIONAL PERU LIBRE              178
# PARTIDO MORADO                                    178
# ACCION POPULAR                                    177
# DEMOCRACIA DIRECTA                                177
# FUERZA POPULAR                                    177
# PARTIDO POPULAR CRISTIANO - PPC                   177
# RENOVACION POPULAR                                177
# RENACIMIENTO UNIDO NACIONAL                       177
# PARTIDO NACIONALISTA PERUANO                      177
# JUNTOS POR EL PERU                                177
# PODEMOS PERU                                      174
# EL FRENTE AMPLIO POR JUSTICIA, VIDA Y LIBERTAD    163
# VICTORIA NACIONAL                                 161
# UNION POR EL PERU                                 157
# AVANZA PAIS - PARTIDO DE INTEGRACION SOCIAL       157
# PERU PATRIA SEGURA                                104
# PARTIDO FRENTE DE LA ESPERANZA 2021                40
# PARTIDO POLÍTICO CONTIGO                           34
# PARTIDO APRISTA PERUANO                            19
# Name: partido, dtype: int64

# %%
### Saliendonos del ejemplo de congresistas: 
pd.set_option('display.max_columns', 28, 'display.max_rows', 28)
## A veces queremos hacer el crosstab entre 2 variables. 
resultado = pd.crosstab(enc_lgbt['depa'], enc_lgbt['depa_nac'], normalize = "columns")

#Asignar como un dataframe el resultado

# %%
type(resultado)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# #### Seleccionando un grupo de columnas
#
# A veces solo queremos ver un grupo de columnas

# %%
cong.columns
# Out:
# Index(['nombre', 'dni', 'partido', 'total_ingreso', 'ingreso_publico',
#        'ingreso_privado', 'renta_publico', 'renta_privado',
#        'otro_ingreso_publico', 'otro_ingreso_privado'],
#       dtype='object')

# %%
peque_lst = ['nombre', 'dni', 'partido']

# %%
cong_small = cong[peque_lst]
# Out:
#                                 nombre       dni                      partido
# 0         SEMPERTEGUI ILATOMA GILBERTO  27428781            VICTORIA NACIONAL
# 1                LUNA GALVEZ JOSE LEON   7246887                 PODEMOS PERU
# 2                KUOMAN SAAVEDRA DAVID   7818712           RENOVACION POPULAR
# 3                  ACUÑA PERALTA CESAR  17903382     ALIANZA PARA EL PROGRESO
# 4       OTIVO MANTURANO TITO ALBERTICO  19873483  RENACIMIENTO UNIDO NACIONAL
# ...                                ...       ...                          ...
# 3311  GUTIERREZ RIVERA SUSANA CAROLINA  44720712                 PODEMOS PERU
# 3312     CISNEROS CALDERON ANIBAL HUGO   8505376  RENACIMIENTO UNIDO NACIONAL
# 3313    GONZALES FLORES LIZBETH ROXANA  48855918                 PODEMOS PERU
# 3314     MELGAR GALVEZ FIORELA JUSETTE  70013249                 PODEMOS PERU
# 3315           HUARI AVILA ERICK DAVID  72765718           RENOVACION POPULAR
#
# [3316 rows x 3 columns]

# %% [markdown]
# Un dataframe está compuesto de varias series (cada columna es una serie diferente)

# %%
type(cong['nombre'])
# Out:
# pandas.core.series.Series

# %%
type(cong['partido'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# #### Seleccionando un grupo de filas
#
# Para dicha tarea, hay 2 formas de hacerlo: usando el ``` iloc``` o el ```loc ```

# %% [markdown]
# ##### Utilizando el iloc
# El iloc ubica las observaciones que corresponden al índice que le indicamos.
# Recordando nuestra base de congresistas:

# %%
#agarrando una fila específica
cong.iloc[0]
# Out:
# nombre                  SEMPERTEGUI ILATOMA GILBERTO
# dni                                         27428781
# partido                            VICTORIA NACIONAL
# total_ingreso                               57560800
# ingreso_publico                              2710800
# ingreso_privado                             14400000
# renta_publico                                      0
# renta_privado                                      0
# otro_ingreso_publico                               0
# otro_ingreso_privado                        40450000
# Name: 0, dtype: object

# %%
#Agarrando una serie de filas en un rango
cong.iloc[0:3]
# Out:
#                          nombre       dni             partido  total_ingreso  \
# 0  SEMPERTEGUI ILATOMA GILBERTO  27428781   VICTORIA NACIONAL       57560800
# 1         LUNA GALVEZ JOSE LEON   7246887        PODEMOS PERU       12428083
# 2         KUOMAN SAAVEDRA DAVID   7818712  RENOVACION POPULAR       10998927
#
#    ingreso_publico  ingreso_privado  renta_publico  renta_privado  \
# 0          2710800         14400000              0              0
# 1                0          1732402              0              0
# 2                0            92096              0              0
#
#    otro_ingreso_publico  otro_ingreso_privado
# 0                     0              40450000
# 1                     0              10695681
# 2                     0              10906831

# %%
# Agarrando observaciones puntuales

cong.iloc[[10,13,3000]]
# Out:
#                              nombre       dni             partido  \
# 10      REGALADO CABRERA JUAN CESAR  27557657   VICTORIA NACIONAL
# 13     RUIZ HUAPAYA RICARDO EUGENIO  25743232  RENOVACION POPULAR
# 3000  CASTILLO RAMOS CARMINA AMELIA   9711715  DEMOCRACIA DIRECTA
#
#       total_ingreso  ingreso_publico  ingreso_privado  renta_publico  \
# 10          1630000           550000                0              0
# 13          1325536                0          1270407              0
# 3000              0                0                0              0
#
#       renta_privado  otro_ingreso_publico  otro_ingreso_privado
# 10          1080000                     0                     0
# 13                0                     0                 55129
# 3000              0                     0                     0

# %% [markdown]
# Utilizando el ```loc```
#
# El ``` loc``` es una forma de ubicar observaciones que se basa en las etiquetas, tanto de columnas como de filas.
#
# Vamos a hacer una nueva indexación de la base de congresistas:

# %%
cong_ind = cong.set_index('dni')

# %%
cong_ind.head(5)
# Out:
#                                   nombre                      partido  \
# dni
# 27428781    SEMPERTEGUI ILATOMA GILBERTO            VICTORIA NACIONAL
# 7246887            LUNA GALVEZ JOSE LEON                 PODEMOS PERU
# 7818712            KUOMAN SAAVEDRA DAVID           RENOVACION POPULAR
# 17903382             ACUÑA PERALTA CESAR     ALIANZA PARA EL PROGRESO
# 19873483  OTIVO MANTURANO TITO ALBERTICO  RENACIMIENTO UNIDO NACIONAL
#
#           total_ingreso  ingreso_publico  ingreso_privado  renta_publico  \
# dni
# 27428781       57560800          2710800         14400000              0
# 7246887        12428083                0          1732402              0
# 7818712        10998927                0            92096              0
# 17903382        9571448                0          3063448              0
# 19873483        7740000          3060000                0              0
#
#           renta_privado  otro_ingreso_publico  otro_ingreso_privado  \
# dni
# 27428781              0                     0              40450000
# 7246887               0                     0              10695681
# 7818712               0                     0              10906831
# 17903382              0                     0               6508000
# 19873483        1800000                     0               2880000
#
#                        nombre partido
# dni
# 27428781            VICTORIA NACIONAL
# 7246887                  PODEMOS PERU
# 7818712            RENOVACION POPULAR
# 17903382     ALIANZA PARA EL PROGRESO
# 19873483  RENACIMIENTO UNIDO NACIONAL

# %%
cong_ind.iloc[0]
# Out:
# nombre                  SEMPERTEGUI ILATOMA GILBERTO
# partido                            VICTORIA NACIONAL
# total_ingreso                               57560800
# ingreso_publico                              2710800
# ingreso_privado                             14400000
# renta_publico                                      0
# renta_privado                                      0
# otro_ingreso_publico                               0
# otro_ingreso_privado                        40450000
# nombre partido                     VICTORIA NACIONAL
# Name: 27428781, dtype: object

# %%
## cong_ind.loc[0] Esto sale error! porque no hay un index = 0 , ya que hemos puesto como index a los DNIS.

# %%
cong_ind.loc[27428781]
# Out:
# nombre                  SEMPERTEGUI ILATOMA GILBERTO
# partido                            VICTORIA NACIONAL
# total_ingreso                               57560800
# ingreso_publico                              2710800
# ingreso_privado                             14400000
# renta_publico                                      0
# renta_privado                                      0
# otro_ingreso_publico                               0
# otro_ingreso_privado                        40450000
# nombre partido                     VICTORIA NACIONAL
# Name: 27428781, dtype: object

# %%
columnas = ["nombre", "partido", "total_ingreso"]
filas = range(0,6)
cong.loc[filas, columnas]

cong.loc[0:5, ['nombre', 'partido', 'total_ingreso']]
# Out:
#                                  nombre                      partido  \
# 0          SEMPERTEGUI ILATOMA GILBERTO            VICTORIA NACIONAL
# 1                 LUNA GALVEZ JOSE LEON                 PODEMOS PERU
# 2                 KUOMAN SAAVEDRA DAVID           RENOVACION POPULAR
# 3                   ACUÑA PERALTA CESAR     ALIANZA PARA EL PROGRESO
# 4        OTIVO MANTURANO TITO ALBERTICO  RENACIMIENTO UNIDO NACIONAL
# 5  LOPEZ ALIAGA CAZORLA RAFAEL BERNARDO           RENOVACION POPULAR
#
#    total_ingreso
# 0       57560800
# 1       12428083
# 2       10998927
# 3        9571448
# 4        7740000
# 5        7648981

# %%
cong.loc[:, columnas]
# Out:
#                                 nombre                      partido  \
# 0         SEMPERTEGUI ILATOMA GILBERTO            VICTORIA NACIONAL
# 1                LUNA GALVEZ JOSE LEON                 PODEMOS PERU
# 2                KUOMAN SAAVEDRA DAVID           RENOVACION POPULAR
# 3                  ACUÑA PERALTA CESAR     ALIANZA PARA EL PROGRESO
# 4       OTIVO MANTURANO TITO ALBERTICO  RENACIMIENTO UNIDO NACIONAL
# ...                                ...                          ...
# 3311  GUTIERREZ RIVERA SUSANA CAROLINA                 PODEMOS PERU
# 3312     CISNEROS CALDERON ANIBAL HUGO  RENACIMIENTO UNIDO NACIONAL
# 3313    GONZALES FLORES LIZBETH ROXANA                 PODEMOS PERU
# 3314     MELGAR GALVEZ FIORELA JUSETTE                 PODEMOS PERU
# 3315           HUARI AVILA ERICK DAVID           RENOVACION POPULAR
#
#       total_ingreso
# 0          57560800
# 1          12428083
# 2          10998927
# 3           9571448
# 4           7740000
# ...             ...
# 3311              0
# 3312              0
# 3313              0
# 3314              0
# 3315              0
#
# [3316 rows x 3 columns]

# %% [markdown]
# #### Filtrando información
#
# Muchas veces querremos quedarnos con un subconjunto de datos que cumplen cierta condición. Las condiciones tienen que evaluarse a un booleano. Por ejemplo:

# %%
condicion = [True] * 4 + [False] * 3312
condicion2 = [True] * 5 + [False] * (len(cong) - 5)
cong[condicion]
# Out:
#                          nombre       dni                   partido  \
# 0  SEMPERTEGUI ILATOMA GILBERTO  27428781         VICTORIA NACIONAL
# 1         LUNA GALVEZ JOSE LEON   7246887              PODEMOS PERU
# 2         KUOMAN SAAVEDRA DAVID   7818712        RENOVACION POPULAR
# 3           ACUÑA PERALTA CESAR  17903382  ALIANZA PARA EL PROGRESO
#
#    total_ingreso  ingreso_publico  ingreso_privado  renta_publico  \
# 0       57560800          2710800         14400000              0
# 1       12428083                0          1732402              0
# 2       10998927                0            92096              0
# 3        9571448                0          3063448              0
#
#    renta_privado  otro_ingreso_publico  otro_ingreso_privado
# 0              0                     0              40450000
# 1              0                     0              10695681
# 2              0                     0              10906831
# 3              0                     0               6508000

# %%
cong.loc[condicion2]
# Out:
#                            nombre       dni                      partido  \
# 0    SEMPERTEGUI ILATOMA GILBERTO  27428781            VICTORIA NACIONAL
# 1           LUNA GALVEZ JOSE LEON   7246887                 PODEMOS PERU
# 2           KUOMAN SAAVEDRA DAVID   7818712           RENOVACION POPULAR
# 3             ACUÑA PERALTA CESAR  17903382     ALIANZA PARA EL PROGRESO
# 4  OTIVO MANTURANO TITO ALBERTICO  19873483  RENACIMIENTO UNIDO NACIONAL
#
#    total_ingreso  ingreso_publico  ingreso_privado  renta_publico  \
# 0       57560800          2710800         14400000              0
# 1       12428083                0          1732402              0
# 2       10998927                0            92096              0
# 3        9571448                0          3063448              0
# 4        7740000          3060000                0              0
#
#    renta_privado  otro_ingreso_publico  otro_ingreso_privado
# 0              0                     0              40450000
# 1              0                     0              10695681
# 2              0                     0              10906831
# 3              0                     0               6508000
# 4        1800000                     0               2880000

# %%
cond = cong['total_ingreso'] > 0

cong[cond]
# Out:
#                               nombre       dni  \
# 0       SEMPERTEGUI ILATOMA GILBERTO  27428781
# 1              LUNA GALVEZ JOSE LEON   7246887
# 2              KUOMAN SAAVEDRA DAVID   7818712
# 3                ACUÑA PERALTA CESAR  17903382
# 4     OTIVO MANTURANO TITO ALBERTICO  19873483
# ...                              ...       ...
# 2741         CONTRERAS CARRION ZULAY  10044135
# 2742     MORALES CHAVEZ CARMEN LUISA  10026610
# 2743        HUAMAN VENTURA ELIZABETH  41478431
# 2744     UNTIVEROS YANCAN RUDDY INES  73032369
# 2745          LERMO LOPEZ JUANA ROSA   9036847
#
#                                              partido  total_ingreso  \
# 0                                  VICTORIA NACIONAL       57560800
# 1                                       PODEMOS PERU       12428083
# 2                                 RENOVACION POPULAR       10998927
# 3                           ALIANZA PARA EL PROGRESO        9571448
# 4                        RENACIMIENTO UNIDO NACIONAL        7740000
# ...                                              ...            ...
# 2741  EL FRENTE AMPLIO POR JUSTICIA, VIDA Y LIBERTAD            800
# 2742                    PARTIDO NACIONALISTA PERUANO            500
# 2743                        ALIANZA PARA EL PROGRESO            484
# 2744                        ALIANZA PARA EL PROGRESO            433
# 2745                 PARTIDO POPULAR CRISTIANO - PPC             51
#
#       ingreso_publico  ingreso_privado  renta_publico  renta_privado  \
# 0             2710800         14400000              0              0
# 1                   0          1732402              0              0
# 2                   0            92096              0              0
# 3                   0          3063448              0              0
# 4             3060000                0              0        1800000
# ...               ...              ...            ...            ...
# 2741                0                0              0            800
# 2742                0                0              0            500
# 2743                0                0              0            484
# 2744                0                0              0            433
# 2745               51                0              0              0
#
#       otro_ingreso_publico  otro_ingreso_privado
# 0                        0              40450000
# 1                        0              10695681
# 2                        0              10906831
# 3                        0               6508000
# 4                        0               2880000
# ...                    ...                   ...
# 2741                     0                     0
# 2742                     0                     0
# 2743                     0                     0
# 2744                     0                     0
# 2745                     0                     0
#
# [2746 rows x 10 columns]

# %%
cond_1 = cong['total_ingreso'] > 0
cond_2 = cong['partido'] == "JUNTOS POR EL PERU"

cong[cond_1 & cond_2]
# Out:
#                                   nombre       dni             partido  \
# 69        DE ECHAVE CACERES JOSE ANTONIO   7886231  JUNTOS POR EL PERU
# 78    QUINTANILLA CHACON ALBERTO EUGENIO   1203752  JUNTOS POR EL PERU
# 94             CASTRO PEREZ HECTOR JAIME   9281542  JUNTOS POR EL PERU
# 104            BAZAN NARRO SIGRID TESORO  72200895  JUNTOS POR EL PERU
# 110    MENDOZA BARDALES KARINA ELIZABETH  21561163  JUNTOS POR EL PERU
# ...                                  ...       ...                 ...
# 2664             AYAY CASAS LUZMILA YALU  16606653  JUNTOS POR EL PERU
# 2671               TTITO PARI ROSA MIRLU  44775467  JUNTOS POR EL PERU
# 2676          JACINTO RODA AMANDA BLANCA   6186181  JUNTOS POR EL PERU
# 2693   VILLAFUERTE CHARCA JOSE ARISTIDES  29292723  JUNTOS POR EL PERU
# 2736   RIMARACHIN CAYATOPA LEYDA GUEILER  41833844  JUNTOS POR EL PERU
#
#       total_ingreso  ingreso_publico  ingreso_privado  renta_publico  \
# 69           336393                0           206228              0
# 78           326109           261959                0              0
# 94           284346                0             6168              0
# 104          251149                0           188910              0
# 110          244800            64800                0              0
# ...             ...              ...              ...            ...
# 2664           4980                0             4980              0
# 2671           4500             4500                0              0
# 2676           4260             4260                0              0
# 2693           3117                0                0              0
# 2736           1000                0                0              0
#
#       renta_privado  otro_ingreso_publico  otro_ingreso_privado
# 69            52319                     0                 77846
# 78                0                     0                 64150
# 94                0                278178                     0
# 104           62239                     0                     0
# 110          180000                     0                     0
# ...             ...                   ...                   ...
# 2664              0                     0                     0
# 2671              0                     0                     0
# 2676              0                     0                     0
# 2693           3117                     0                     0
# 2736           1000                     0                     0
#
# [156 rows x 10 columns]
